# %% [markdown]
# # Sanfrancisco Biking - Bigquery

# %% [markdown]
# The goal of this shorter project is to showcase the following skills of mine:
# * Connecting to Google Cloud - Bigquery API
# * Limiting how much data we can fetch from the Google API
# * Writing SQL queries

# %% [markdown]
# ### 1. Import the librarys

# %%
import os
from google.cloud import bigquery

# %% [markdown]
# ### 2. With the credentials file make the authorization to google.

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'application_default_credentials.json'

# %% [markdown]
# ### 3. We are going to use the sfbiking project

# %%
client = bigquery.Client(project = 'sfbiking')

# %% [markdown]
# ### 4. Create the safe_config instance, so we can add the limit to all of our future queries.

# %%
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)

# %% [markdown]
# ### Inspect the data

# %%
df_head_query = """
                    SELECT *
                          FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                          LIMIT 5
                  """

# %%
query1 = client.query(df_head_query, job_config = safe_config).result().to_dataframe()
query1
# Out:
#    trip_id  duration_sec                start_date  \
# 0  1235850          1540 2016-06-11 08:19:00+00:00
# 1  1219337          6324 2016-05-29 12:49:00+00:00
# 2   793762        115572 2015-06-04 09:22:00+00:00
# 3   453845         54120 2014-09-15 16:53:00+00:00
# 4  1245113          5018 2016-06-17 20:08:00+00:00
#
#                   start_station_name  start_station_id  \
# 0  San Jose Diridon Caltrain Station                 2
# 1  San Jose Diridon Caltrain Station                 2
# 2  San Jose Diridon Caltrain Station                 2
# 3  San Jose Diridon Caltrain Station                 2
# 4  San Jose Diridon Caltrain Station                 2
#
#                    end_date                   end_station_name  \
# 0 2016-06-11 08:45:00+00:00  San Jose Diridon Caltrain Station
# 1 2016-05-29 14:34:00+00:00  San Jose Diridon Caltrain Station
# 2 2015-06-05 17:28:00+00:00  San Jose Diridon Caltrain Station
# 3 2014-09-16 07:55:00+00:00  San Jose Diridon Caltrain Station
# 4 2016-06-17 21:32:00+00:00  San Jose Diridon Caltrain Station
#
#    end_station_id  bike_number zip_code subscriber_type
# 0               2          124    15206        Customer
# 1               2          174    55416        Customer
# 2               2          190    95391        Customer
# 3               2          127       81        Customer
# 4               2          153    95070        Customer

# %% [markdown]
# ### Find how many distinct records do we have.

# %%
query2_sql = """
                    SELECT COUNT(DISTINCT trip_id) AS Num_of_trips
                          FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                  """

# %%
query2 = client.query(query2_sql, job_config = safe_config).result().to_dataframe()
query2.head()
# Out:
#    Num_of_trips
# 0        983648

# %% [markdown]
# ### Find the minimum time

# %%
query3_sql = """
                    SELECT MIN(DATE(start_date)) AS Earliest_time, MAX(DATE(end_date)) AS Latest_time
                          FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                  """

# %%
query3 = client.query(query3_sql, job_config = safe_config).result().to_dataframe()
query3.head()
# Out:
#   Earliest_time Latest_time
# 0    2013-08-29  2016-08-31

# %% [markdown]
# ### Find the number of bikes in the bike fleet.

# %%
query4_sql = """
                    SELECT COUNT(DISTINCT bike_number) AS Num_of_bikes
                          FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                  """

# %%
query4 = client.query(query4_sql, job_config = safe_config).result().to_dataframe()
query4.head()
# Out:
#    Num_of_bikes
# 0           700

# %% [markdown]
# ### Find which Zip Code is the most common.

# %%
query5_sql = """
                    SELECT COUNT(*) AS Zip_code_count, zip_code
                          FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                          GROUP BY zip_code
                          ORDER BY 1 DESC
                  """

# %%
query5 = client.query(query5_sql, job_config = safe_config).result().to_dataframe()
query5.head()
# Out:
#    Zip_code_count zip_code
# 0          106913    94107
# 1           61232    94105
# 2           46544    94133
# 3           38072    94103
# 4           33642    94111

# %% [markdown]
# ### Find all the unique trips and their average,max,min trip duration as well as how many times that trip was taken.

# %%
 #Highest, lowest and the average time for each unique start-end station
query6_sql = """ 
                SELECT start_station_name, end_station_name, AVG(duration_sec) AS Average_duration_in_sec, MAX(duration_sec) AS Highest_Time, MIN(duration_sec) AS Lowest_Time, COUNT(*) AS Trip_count
                    FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                    GROUP BY start_station_name, end_station_name
                    ORDER BY Average_duration_in_sec
                    """

# %%
query6 = client.query(query6_sql, job_config = safe_config).result().to_dataframe()
query6
# Out:
#                     start_station_name  \
# 0          Cyril Magnin St at Ellis St
# 1             S. Market St at Park Ave
# 2                  San Salvador at 1st
# 3          5th S at E. San Salvador St
# 4                      Beale at Market
# ...                                ...
# 2134    Mountain View Caltrain Station
# 2135          South Van Ness at Market
# 2136   Santa Clara County Civic Center
# 2137  Castro Street and El Camino Real
# 2138       Redwood City Medical Center
#
#                                    end_station_name  Average_duration_in_sec  \
# 0                                Powell Street BART                81.000000
# 1                                  Adobe on Almaden               134.000000
# 2                       5th S at E. San Salvador St               142.000000
# 3                        SJSU - San Salvador at 9th               150.000000
# 4     Temporary Transbay Terminal (Howard at Beale)               188.146452
# ...                                             ...                      ...
# 2134              San Jose Diridon Caltrain Station            101207.500000
# 2135                                  2nd at Folsom            104964.343373
# 2136                California Ave Caltrain Station            169308.000000
# 2137                                  Howard at 2nd            179212.500000
# 2138                     SJSU - San Salvador at 9th            229914.000000
#
#       Highest_Time  Lowest_Time  Trip_count
# 0               81           81           1
# 1              180           88           2
# 2              142          142           1
# 3              150          150           1
# 4            14150           68        1550
# ...            ...          ...         ...
# 2134        189876        12539           2
# 2135      17270400          590         166
# 2136        169308       169308           1
# 2137        179330       179095           2
# 2138        229914       229914           1
#
# [2139 rows x 6 columns]

# %% [markdown]
# ### Same as the previous query but grouped by Trip_count

# %%
query7_sql = """ 
                SELECT start_station_name, end_station_name, AVG(duration_sec) AS Average_duration_in_sec, MAX(duration_sec) AS Highest_Time, MIN(duration_sec) AS Lowest_Time, COUNT(*) AS Trip_count
                    FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                    GROUP BY start_station_name, end_station_name
                    ORDER BY Trip_count DESC
                    """

# %%
query7 = client.query(query7_sql, job_config = safe_config).result().to_dataframe()
query7
# Out:
#                                  start_station_name  \
# 0              Harry Bridges Plaza (Ferry Building)
# 1           San Francisco Caltrain 2 (330 Townsend)
# 2                                   2nd at Townsend
# 3              Harry Bridges Plaza (Ferry Building)
# 4                            Embarcadero at Sansome
# ...                                             ...
# 2134                       South Van Ness at Market
# 2135  Yerba Buena Center of the Arts (3rd @ Howard)
# 2136              Civic Center BART (7th at Market)
# 2137                              Steuart at Market
# 2138                                  Market at 4th
#
#                           end_station_name  Average_duration_in_sec  \
# 0                   Embarcadero at Sansome              1188.003825
# 1                          Townsend at 7th               306.665961
# 2     Harry Bridges Plaza (Ferry Building)               581.754856
# 3                          2nd at Townsend               637.523229
# 4                        Steuart at Market               511.009019
# ...                                    ...                      ...
# 2134           Cyril Magnin St at Ellis St               439.000000
# 2135           Cyril Magnin St at Ellis St               359.000000
# 2136           Cyril Magnin St at Ellis St               303.000000
# 2137           Cyril Magnin St at Ellis St               766.000000
# 2138           Cyril Magnin St at Ellis St              1209.000000
#
#       Highest_Time  Lowest_Time  Trip_count
# 0            71180          219        9150
# 1            91522          144        8508
# 2            71188          294        7620
# 3            37907          325        6888
# 4            78123          228        6874
# ...            ...          ...         ...
# 2134           439          439           1
# 2135           359          359           1
# 2136           303          303           1
# 2137           766          766           1
# 2138          1209         1209           1
#
# [2139 rows x 6 columns]

# %% [markdown]
# ### In each year how many Subscriber and Customer trips did we have.

# %%
query8_sql = """ 
                SELECT SUBSTR(CAST(start_date AS STRING), 1, 4) AS Year, subscriber_type, AVG(duration_sec) AS Average_duration_in_sec, MAX(duration_sec) AS Highest_Time, MIN(duration_sec) AS Lowest_Time, COUNT(*) AS Trip_count
                    FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                    GROUP BY Year, subscriber_type
                    ORDER BY Trip_count DESC
                    """

# %%
query8 = client.query(query8_sql, job_config = safe_config).result().to_dataframe()
query8
# Out:
#    Year subscriber_type  Average_duration_in_sec  Highest_Time  Lowest_Time  \
# 0  2015      Subscriber               584.849164       1852590           60
# 1  2014      Subscriber               588.627841        716480           60
# 2  2016      Subscriber               562.748881         85900           60
# 3  2013      Subscriber               602.255430        619322           60
# 4  2014        Customer              4238.843750      17270400           60
# 5  2015        Customer              3626.959660       2137000           60
# 6  2013        Customer              3541.320136        722236           62
# 7  2016        Customer              2977.836925         86325           60
#
#    Trip_count
# 0      305722
# 1      277763
# 2      187290
# 3       76064
# 4       48576
# 5       40530
# 6       24499
# 7       23204

# %% [markdown]
# ### Query to track beginning and ending stations on October 25, 2015, for each bike

# %%
query9 = """
                  SELECT bike_number,
                      TIME(start_date) AS trip_time,
                      FIRST_VALUE(start_station_id)
                          OVER (
                               PARTITION BY bike_number
                               ORDER BY start_date
                               ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
                               ) AS first_station_id,
                      LAST_VALUE(end_station_id)
                          OVER (
                               PARTITION BY bike_number
                               ORDER BY start_date
                               ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
                               ) AS last_station_id,
                      start_station_id,
                      end_station_id
                  FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                  WHERE DATE(start_date) = '2015-10-25' 
                  """

# %%
query9 = client.query(query9, job_config = safe_config).result().to_dataframe()
query9.head()
# Out:
#    bike_number trip_time  first_station_id  last_station_id  start_station_id  \
# 0          205  14:34:00                14               14                14
# 1          530  11:18:00                82               77                82
# 2          530  12:00:00                82               77                50
# 3          530  18:52:00                82               77                73
# 4          581  12:41:00                77               73                77
#
#    end_station_id
# 0              14
# 1              50
# 2              73
# 3              77
# 4              60

# %% [markdown]
# ### Query to count the (cumulative) number of trips per day

# %%
num_trips_query = """
                  WITH trips_by_day AS
                  (
                  SELECT DATE(start_date) AS trip_date,
                      COUNT(*) as num_trips
                  FROM `bigquery-public-data.san_francisco.bikeshare_trips`
                  WHERE EXTRACT(YEAR FROM start_date) = 2015
                  GROUP BY trip_date
                  )
                  SELECT *,
                      SUM(num_trips) 
                          OVER (
                               ORDER BY trip_date
                               ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
                               ) AS cumulative_trips
                      FROM trips_by_day
                  """

# %%
query2 = client.query(num_trips_query, job_config = safe_config).result().to_dataframe()
query2.head()
# Out:
#     trip_date  num_trips  cumulative_trips
# 0  2015-05-28       1288            144866
# 1  2015-11-21        277            323385
# 2  2015-01-20       1213             16742
# 3  2015-11-22        244            323629
# 4  2015-12-24        124            344312
